# %% [markdown]
# # Optimization of Lennard-Jones potential for low density limit

# %%
# %matplotlib inline
from itertools import product
import copy
import math
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Second virial coefficient as a function of temperature and LJ parameters

# %%
def pars_eff(sig, eps, T):
    """Effective temperature-dependent parameters"""
    
    # effective sigma & epsilon 
    alpha = 1.444*1e-30  # m^3
    mu = 1.855*3.1623e-25  # (J*m^3)^(1/2)
    kb = 1.380649e-23
    
    ST = 1 + 6*alpha*mu**2/(12*kb*1e-60)/(eps*sig**6)
    ST += mu**4/(12*kb**2*1e-60)/(T*eps*sig**6)
#    ST = 1.0988883 + 284.600188/T 

    sig_eff = sig*ST**(-1/6)
    eps_eff = eps*ST**2
    
    return sig_eff, eps_eff

# %%
def b2n(T, sig=1.0, eps=1.0, verbose=False):
    """Returns second virial coefficient of Lennard-Jones fluid

    Parameters
    ----------
    T : float
        Absolute temperature (K)
    sig : float
        Size parameter (Angstrom)
    eps : float
        Energy parameter (K)

    Returns
    -------
    b2 : float
        second virial coefficient (m^3/mol)
    """
    
    sig_eff, eps_eff = pars_eff(sig, eps, T)
    
    # Reduced temperature
    #Tr = T*8.314472/(eps*1000.0)
    Tr = T/eps_eff
    
    # Check if the reduced temperature is safe range
    if verbose and (Tr < 0.3 or Tr > 10000.0):
        print(f'Temperature {Tr} K is not in range 298-3000 K.')

    # Reduced virial coefficient
    
    Br = 7.8063*(1/Tr)**0.5 - 39.354*(1/Tr) + 92.147*(1/Tr)**1.5 - 121.58*(1/Tr)**2 
    Br += 72.269*(1/Tr)**2.5 - 0.37916*(1/Tr)**5 - 22.044*(1/Tr)**3.5 + 8.5833*(1/Tr)**4

#     Br  = 1.9863*Tr**(-0.25) - 1.5985*Tr**(-0.5) - 6.7636*Tr**(-1.5)
#     Br += 8.0952*Tr**(-2.0) - 4.8797*Tr**(-2.5) + 0.89417*Tr**(-3.5)
#     Br -= 0.25573*Tr**(-4.0)
#     Br -= 0.015386*Tr**(-5.0)

    Na = 6.0221409e23
    b0 = 2*np.pi*Na*(sig_eff*1e-10)**3/3
    
    B2 = Br*b0
    
    return B2

# %%
def density(P, T, b2):
    """
    Uses SI units
    """
    
    R = 8.314472
    rho = (-1 + np.sqrt(1 + 4*P*b2/(R*T))) / (2*b2)
    
    return rho

# %% [markdown]
# ## Reduced collision integrals for LJ potential

# %%
class Omega:
    """Collision integrals for Lennard-Jones potential"""
    
    def __init__(self, coeffs):
        if isinstance(coeffs, dict):
            self.coeffs = coeffs
        elif isinstance(coeffs, np.ndarray):
            self.coeffs = self.make_dict(coeffs)
        else:
            raise TypeError
            
    def make_dict(self, coeffs_array):
        """Creates a dictionary from supplied coefficient ndarray.
        
        Works for a particular structure of ndarray - should be modified
        if other format is used.
        """
        
        ls_tuples = [(1, i) for i in range(1, 8)] + [(2, i) for i in range(2, 7)] + [(3,3), (3,4), (3,5), (4,4)]
        b_list = [1, 3, 5, 8, 10, 6]
        c_list = [2, 4, 7, 9, 11, 12]
        b_fac = np.array([1., 1., 10., 10., 100., 1000.])
        c_fac = np.array([1., 10., 10., 100., 1000., 10000.])

        coeffs = {}
        for i in range(16):
            ls = ls_tuples[i]
            coeffs[ls] = {}
            coeffs[ls]['a'] = coeffs_array[0,i]
            coeffs[ls]['b'] = coeffs_array[b_list, i]/b_fac
            coeffs[ls]['c'] = coeffs_array[c_list, i]/c_fac

        return coeffs
        
    def get(self, Tr, l=1, s=1):
        """Returns collision integral for a given temperature"""
        coeff = self.coeffs[(l, s)]
        b = coeff['b']
        c = coeff['c']
        omega = coeff['a']
        omega += sum([b[k-1]*Tr**(-k) + c[k-1]*np.log(Tr)**k for k in range(1, 7)])
    
        return omega

# %%
# read data from file
cc = np.loadtxt('../data/raw/coeffs_num.txt')

# %%
omg = Omega(cc)

# %%
omg.get(100.0, 2, 2)
# Out:
# 0.5851365357380904

# %%
def diff_correction(Tr):
    
    o_11 = omg.get(Tr, 1, 1)
    o_12 = omg.get(Tr, 1, 2)
    o_13 = omg.get(Tr, 1, 3)
    o_22 = omg.get(Tr, 2, 2)
    
    A = o_22/o_11
    B = (5*o_12 - 4*o_13)/o_11
    C = o_12/o_11
    
    fd = 1 - (6*C - 5)**2 / (55 - 12*B + 16*A)
    fd /= 1.0
    
    return fd

# %% [markdown]
# ## Target data
#
# * Second virial coefficient over a range of temperatures (i.e., low density equation of state)
# * Low-density viscosities

# %%
b2_experiment = np.loadtxt('../data/raw/b2_h2o.txt')

# %%
# construct target data, with Pressure set to 1 Pa and b2 set in SI units (m^3/mol converted from cm^3/mol)
target_eos = [(100, T, b2*1e-6) for T, b2 in b2_experiment]

# %% [markdown]
# ## Optimization
#
# * Optimize over a range of temperatures (and pressures)

# %%
def loss_rho_full(params, target):
    """
    Statistical distance based on the equation of state
    """
    R = 8.314472
        
    s2_list = []
    log_list = []
    for P, T, b2_t in target:
        if T < 800.0:
        #if T < 1000.0:
            continue
            
        rho_ig = np.longdouble(P/(R*T))
            
        b2_m = b2n(T, params[0], params[1])
        
        rho_m = density(P, T, b2_m)/rho_ig
        rho_t = density(P, T, b2_t)/rho_ig
        
        var_m = rho_m/(1+2*b2_m*rho_m*rho_ig)
        var_t = rho_t/(1+2*b2_t*rho_t*rho_ig)
        
        #cb = np.exp(-(rho_m - rho_t)**2/(4*(var_m + var_t)) + np.log(np.sqrt(2*np.sqrt(var_m*var_t)/(var_m + var_t))))
        #cb *= np.sqrt(2*np.sqrt(var_m*var_t)/(var_m + var_t))
        
        #print(P, T, rho_t, var_t/rho_t**2, var_t, b2_t*1e6, (rho_m-rho_t)**2, (rho_m - rho_t)**2/(4*(var_m + var_t)))
        
        #print((rho_m - rho_t)**2/(4*(var_m + var_t)))
        #print('rho', rho_t, rho_m)
        #print('fac', -1e22*(rho_m - rho_t)**2/(4*(var_m + var_t)), np.sqrt(2*np.sqrt(var_m*var_t)/(var_m + var_t)))
        #print('dat', P, T, rho_t, b2_t*1e6, b2_m*1e6, rho_m - rho_t, cb, *params)

        #s2 += np.arccos(cb)**2
        
        #print('x^2', (rho_m - rho_t)**2/(4*(var_m + var_t)))
        #print('log(x)', np.log(np.sqrt(2*np.sqrt(var_m*var_t)/(var_m + var_t))))

        s2_list.append(rho_ig*(rho_m - rho_t)**2/(4*(var_m + var_t)))
        #log_list.append(-0.25*np.log(4*(var_m*var_t)/(var_m + var_t)**2))
        
        #print('var', type(np.log(var_m)), 4*(var_m*var_t)/(var_m + var_t)**2)
        log_list.append(-0.25*(np.log(4) + np.log(var_m) + np.log(var_t) - 2*np.log(var_m + var_t)))

    
    s2 = math.fsum(s2_list + log_list)
    #s2 = sum(s2_list + log_list)
    #s2 = sum(s2_list.sort())
    s2 /= len(target)

    #print('s2:', s2, type(s2), math.fsum(s2_list)/len(target), math.fsum(log_list)/len(target))
    return s2

# %%
def loss_rho(params, target):
    """
    Statistical distance based on the equation of state
    """
    R = 8.314472
        
    s2_list = []
    log_list = []
    for P, T, b2_t in target:
        if T < 800.0:
        #if T < 1000.0:
            continue
            
        rho_ig = np.longdouble(P/(R*T))
            
        b2_m = b2n(T, params[0], params[1])
        
        delta_m = (density(P, T, b2_m) - rho_ig)/rho_ig
        delta_t = (density(P, T, b2_t) - rho_ig)/rho_ig
        
        delta_ave = 0.5*(delta_m + delta_t)
        
        var_m = 1 + delta_m - 2*b2_m*rho_ig*(1 + delta_m)
        var_t = 1 + delta_t - 2*b2_t*rho_ig*(1 + delta_t)

        dvar_m = var_m - 1
        dvar_t = var_t - 1
        
        ds2 = rho_ig*(delta_m - delta_t)**2/(var_m + var_t)
        
        s2_list.append(ds2)
        
        dlg = 0.25*(dvar_m + dvar_t - dvar_m - dvar_t)
        log_list.append(-0.25*np.log(4*(var_m*var_t)/(var_m + var_t)**2))

        
        
        var_m = rho_m/(1+2*b2_m*rho_m*rho_ig)
        var_t = rho_t/(1+2*b2_t*rho_t*rho_ig)
        
        #cb = np.exp(-(rho_m - rho_t)**2/(4*(var_m + var_t)) + np.log(np.sqrt(2*np.sqrt(var_m*var_t)/(var_m + var_t))))
        #cb *= np.sqrt(2*np.sqrt(var_m*var_t)/(var_m + var_t))
        
        #print(P, T, rho_t, var_t/rho_t**2, var_t, b2_t*1e6, (rho_m-rho_t)**2, (rho_m - rho_t)**2/(4*(var_m + var_t)))
        
        #print((rho_m - rho_t)**2/(4*(var_m + var_t)))
        #print('rho', rho_t, rho_m)
        #print('fac', -1e22*(rho_m - rho_t)**2/(4*(var_m + var_t)), np.sqrt(2*np.sqrt(var_m*var_t)/(var_m + var_t)))
        #print('dat', P, T, rho_t, b2_t*1e6, b2_m*1e6, rho_m - rho_t, cb, *params)

        #s2 += np.arccos(cb)**2
        
        #print('x^2', (rho_m - rho_t)**2/(4*(var_m + var_t)))
        #print('log(x)', np.log(np.sqrt(2*np.sqrt(var_m*var_t)/(var_m + var_t))))

        log_list.append(-0.25*np.log(4*(var_m*var_t)/(var_m + var_t)**2))
        
        #print('var', type(np.log(var_m)), 4*(var_m*var_t)/(var_m + var_t)**2)
        #log_list.append(-0.25*(np.log(4) + np.log(var_m) + np.log(var_t) - 2*np.log(var_m + var_t)))

    
    s2 = math.fsum(s2_list + log_list)
    #s2 = sum(s2_list + log_list)
    #s2 = sum(s2_list.sort())
    s2 /= len(target)

    #print('s2:', s2, type(s2), math.fsum(s2_list)/len(target), math.fsum(log_list)/len(target))
    return s2

# %%
def loss_b2_const_rho(params, target):
    # ignoring prefactor V/(k_B)^3
    # If P is only one (P->0), it can be included in the prefactor
    loss = 0.0
    for P, T, b2_t in target:
        #if T < 647.0:
        if T < 1000.0:
            continue
        
        b2_m = b2n(T, params[0], params[1])

        loss += (b2_m - b2_t)**2 

    return loss

# %%
def loss_b2_const_press(params, target):
    # ignoring prefactor V/(k_B)^3
    # If P is only one (P->0), it can be included in the prefactor
    loss = 0.0
    for P, T, b2_t in target:
        #if T < 647.0:
        if T < 1000.0:
            continue
        
        b2_m = b2n(T, params[0], params[1])
        loss += (P/T)**2 * (b2_m - b2_t)**2 

    return loss

# %%
# initial parameters (sigma (A), epsilon (K))
params_in = np.array([2.92, 293.7])

# %%
result = minimize(loss_b2_const_rho, params_in, method='Nelder-Mead', args=(target_eos,))
result
# Out:
#  final_simplex: (array([[  3.11323459, 329.98963339],
#        [  3.11323488, 329.98969406],
#        [  3.1132347 , 329.98968302]]), array([2.09089946e-12, 2.09089946e-12, 2.09089946e-12]))
#            fun: 2.0908994565426557e-12
#        message: 'Optimization terminated successfully.'
#           nfev: 97
#            nit: 51
#         status: 0
#        success: True
#              x: array([  3.11323459, 329.98963339])

# %%
params_b2rho = result['x']

# %%
result = minimize(loss_b2_const_press, params_in, method='Nelder-Mead', args=(target_eos,))
result
# Out:
#  final_simplex: (array([[  3.15789174, 338.72007635],
#        [  3.15789189, 338.72006828],
#        [  3.15789129, 338.71999677]]), array([7.64181719e-15, 7.64181719e-15, 7.64181719e-15]))
#            fun: 7.64181718966269e-15
#        message: 'Optimization terminated successfully.'
#           nfev: 94
#            nit: 49
#         status: 0
#        success: True
#              x: array([  3.15789174, 338.72007635])

# %%
params_b2press = result['x']

# %%
#result = minimize(loss_rho, params_best, method='Nelder-Mead', args=(target_eos,), tol=1e-15, options={'maxiter':1e4})
#result

# %%
#params_best = np.array([3.10920117, 273.45076171])

# %%
#params_optimal = result['x']

# %%
# Model virial coefficient
b2_model = []
b2_start = []
b2_b2opt = []
#b2_dens = []
for P, T, b2_t in target_eos:
#    if T < 647.0:
#        continue
    b2_model.append(b2n(T, params_b2press[0], params_b2press[1]))
    b2_start.append(b2n(T, params_in[0], params_in[1]))
    b2_b2opt.append(b2n(T, params_b2rho[0], params_b2rho[1]))
#    b2_dens.append(b2n(T, params_best[0], params_best[1]))

b2_model = np.array(b2_model)
b2_start = np.array(b2_start)
b2_b2opt = np.array(b2_b2opt)
#b2_dens = np.array(b2_dens)

# %%
plt.figure(figsize=(20,15))
Temp = np.array(target_eos)[:,1]
plt.plot(Temp, np.array(target_eos)[:,2]*1e6, 'ko--', ms=8, label='Target (experiment)')
plt.plot(Temp, b2_start*1e6, 'rs--', ms=8, label='Ariel\'s')
plt.plot(Temp, b2_model*1e6, 'gv--', ms=8, label='B2 (const P)')
plt.plot(Temp, b2_b2opt*1e6, 'bx--', ms=8, label='B2 (const rho)')
#plt.plot(Temp, b2_dens*1e6, 'mx--', ms=8, label='Looks best')

plt.xlabel('T[K]', fontsize=20)
plt.ylabel('$B_2$[cm$^3$/mol]', fontsize=20)
plt.legend(fontsize=20)

plt.ylim(-100, 20)
plt.xlim(650,3000)
plt.title('Second virial coefficient optimized in T-range 1000 - 3000K', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Second virial coefficient optimized in T-range 1000 - 3000K')

# %%
print(np.linspace(2.83, 4.0, 40))
print(np.linspace(262., 369., 40))
# Out:
# [2.83 2.86 2.89 2.92 2.95 2.98 3.01 3.04 3.07 3.1  3.13 3.16 3.19 3.22
#  3.25 3.28 3.31 3.34 3.37 3.4  3.43 3.46 3.49 3.52 3.55 3.58 3.61 3.64
#  3.67 3.7  3.73 3.76 3.79 3.82 3.85 3.88 3.91 3.94 3.97 4.  ]
# [262.         264.74358974 267.48717949 270.23076923 272.97435897
#  275.71794872 278.46153846 281.20512821 283.94871795 286.69230769
#  289.43589744 292.17948718 294.92307692 297.66666667 300.41025641
#  303.15384615 305.8974359  308.64102564 311.38461538 314.12820513
#  316.87179487 319.61538462 322.35897436 325.1025641  327.84615385
#  330.58974359 333.33333333 336.07692308 338.82051282 341.56410256
#  344.30769231 347.05128205 349.79487179 352.53846154 355.28205128
#  358.02564103 360.76923077 363.51282051 366.25641026 369.        ]

# %%
sig_list = np.linspace(2.95, 3.35, 40)
eps_list = np.linspace(262., 369., 40)

n_sig = len(sig_list)
n_eps = len(eps_list)

s2_profiles = np.empty((n_sig, n_eps), dtype=float)
r2_profiles = np.empty((n_sig, n_eps), dtype=float)

pars_profiles = np.empty((n_sig, n_eps, 2), dtype=float)
for i, j in product(range(n_sig), range(n_eps)):
    sig = sig_list[i]
    eps = eps_list[j]
    pars_in = np.array([sig, eps])
    #print(pars_in)
    s2 = loss_b2_const_press(pars_in, target_eos)
    r2 = loss_b2_const_rho(pars_in, target_eos)
    s2_profiles[i, j] = s2
    r2_profiles[i, j] = r2
    pars_profiles[i, j, :] = pars_in

# %%
import matplotlib.ticker as ticker

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,10))
indices = np.unravel_index(np.argmin(s2_profiles, axis=None), s2_profiles.shape)
max_val = np.max(s2_profiles)
s2_profiles_x = copy.copy(s2_profiles)
s2_profiles_x[indices] = max_val
im = axes[0].matshow(s2_profiles_x)
axes[0].xaxis.set_major_locator(ticker.MultipleLocator(5))
axes[0].yaxis.set_major_locator(ticker.MultipleLocator(5))
axes[0].set_xticklabels([str(round(v-0.15, 2)) for v in sig_list[::5]])
axes[0].set_yticklabels([str(round(v-15, 2)) for v in eps_list[::5]])

#axes.set_yticklabels(ticklabels)
axes[0].set_xlabel('$\sigma [\AA]$ ', fontsize=15)
axes[0].set_ylabel('$\epsilon [K]$', fontsize=15)

indices = np.unravel_index(np.argmin(r2_profiles, axis=None), r2_profiles.shape)
max_val = np.max(r2_profiles)
r2_profiles_x = copy.copy(r2_profiles)
r2_profiles_x[indices] = max_val
im = axes[1].matshow(r2_profiles_x)
axes[1].xaxis.set_major_locator(ticker.MultipleLocator(5))
axes[1].yaxis.set_major_locator(ticker.MultipleLocator(5))
axes[1].set_xticklabels([str(round(v-0.15, 2)) for v in sig_list[::5]])
axes[1].set_yticklabels([str(round(v-15, 2)) for v in eps_list[::5]])

#axes.set_yticklabels(ticklabels)
axes[1].set_xlabel('$\sigma [\AA]$ ', fontsize=15)
axes[1].set_ylabel('$\epsilon [K]$', fontsize=15)

pars_optimal = pars_profiles[indices]
print(pars_optimal)
#axes.set_title('Total\n Optimal parameters: ' + str(params_dens), fontsize=20)
# Out:
# [  3.11410256 330.58974359]

# %%
np.min(s2_profiles)
# Out:
# 2.286307228323862e-17

# %%
visc = pd.read_csv('../data/raw/Hellmann_zero_visco.txt')

# %%
visc
# Out:
#       T(K)     T/Tc  (T/Tc)^0.5  (T/Tc)^(-0.5)  (T/Tc)^-1  (T/Tc)^(-1.5)  \
# 0    300.0  0.46361     0.68089        1.46870    2.15700        3.16790
# 1    325.0  0.50224     0.70869        1.41110    1.99110        2.80950
# 2    350.0  0.54088     0.73544        1.35970    1.84880        2.51390
# 3    375.0  0.57951     0.76126        1.31360    1.72560        2.26680
# 4    400.0  0.61815     0.78622        1.27190    1.61770        2.05760
# 5    425.0  0.65678     0.81042        1.23390    1.52260        1.87880
# 6    450.0  0.69541     0.83392        1.19920    1.43800        1.72440
# 7    475.0  0.73405     0.85677        1.16720    1.36230        1.59010
# 8    500.0  0.77268     0.87902        1.13760    1.29420        1.47230
# 9    525.0  0.81132     0.90073        1.11020    1.23260        1.36840
# 10   550.0  0.84995     0.92193        1.08470    1.17650        1.27620
# 11   575.0  0.88859     0.94265        1.06080    1.12540        1.19390
# 12   600.0  0.92722     0.96292        1.03850    1.07850        1.12000
# 13   625.0  0.96585     0.98278        1.01750    1.03540        1.05350
# 14   650.0  1.00450     1.00220        0.99776    0.99553        0.99331
# 15   675.0  1.04310     1.02130        0.97911    0.95866        0.93864
# 16   700.0  1.08180     1.04010        0.96147    0.92442        0.88880
# 17   725.0  1.12040     1.05850        0.94475    0.89255        0.84323
# 18   750.0  1.15900     1.07660        0.92887    0.86279        0.80142
# 19   775.0  1.19770     1.09440        0.91376    0.83496        0.76296
# 20   800.0  1.23630     1.11190        0.89937    0.80887        0.72748
# 21   850.0  1.31360     1.14610        0.87252    0.76129        0.66424
# 22   900.0  1.39080     1.17930        0.84794    0.71900        0.60966
# 23   950.0  1.46810     1.21170        0.82532    0.68115        0.56217
# 24  1000.0  1.54540     1.24310        0.80442    0.64710        0.52054
# 25  1100.0  1.69990     1.30380        0.76699    0.58827        0.45119
# 26  1200.0  1.85440     1.36180        0.73433    0.53925        0.39599
# 27  1300.0  2.00900     1.41740        0.70553    0.49777        0.35119
# 28  1400.0  2.16350     1.47090        0.67986    0.46221        0.31424
# 29  1500.0  2.31800     1.52250        0.65681    0.43140        0.28335
# 30  1600.0  2.47260     1.57240        0.63595    0.40444        0.25720
# 31  1800.0  2.78170     1.66780        0.59958    0.35950        0.21555
# 32  2000.0  3.09070     1.75800        0.56881    0.32355        0.18404
# 33  2500.0  3.86340     1.96560        0.50876    0.25884        0.13169
#
#     (T/Tc)^(-2)   ()^-2.5      ()^-3    ()^-3.5  viscosity(micro-Pas)  \
# 0      4.652600  6.833100  10.036000  14.739000                9.7331
# 1      3.964300  5.593900   7.893300  11.138000               10.5960
# 2      3.418200  4.647800   6.319800   8.593200               11.4810
# 3      2.977700  3.911500   5.138200   6.749600               12.3890
# 4      2.617100  3.328700   4.233800   5.384900               13.3200
# 5      2.318200  2.860500   3.529700   4.355400               14.2740
# 6      2.067800  2.479700   2.973500   3.565700               15.2490
# 7      1.855900  2.166100   2.528300   2.951000               16.2440
# 8      1.674900  1.905400   2.167700   2.466000               17.2540
# 9      1.519200  1.686600   1.872500   2.078900               18.2780
# 10     1.384200  1.501500   1.628600   1.766500               19.3140
# 11     1.266500  1.343500   1.425300   1.512000               20.3570
# 12     1.163100  1.207900   1.254400   1.302800               21.4070
# 13     1.072000  1.090700   1.109900   1.129300               22.4610
# 14     0.991080  0.988870   0.986660   0.984450               23.5160
# 15     0.919030  0.899830   0.881040   0.862640               24.5700
# 16     0.854560  0.821630   0.789970   0.759530               25.6230
# 17     0.796640  0.752620   0.711040   0.671750               26.6720
# 18     0.744410  0.691460   0.642280   0.596590               27.7160
# 19     0.697160  0.637040   0.582100   0.531910               28.7530
# 20     0.654270  0.588430   0.529220   0.475970               29.7840
# 21     0.579560  0.505680   0.441210   0.384970               31.8200
# 22     0.516950  0.438340   0.371690   0.315170               33.8180
# 23     0.463970  0.382920   0.316040   0.260830               35.7760
# 24     0.418730  0.336840   0.270960   0.217970               37.6910
# 25     0.346060  0.265420   0.203580   0.156140               41.3900
# 26     0.290790  0.213530   0.156810   0.115150               44.9200
# 27     0.247770  0.174810   0.123330   0.087014               48.2930
# 28     0.213640  0.145250   0.098747   0.067134               51.5230
# 29     0.186100  0.122230   0.080285   0.052732               54.6240
# 30     0.163570  0.104020   0.066152   0.042070               57.6120
# 31     0.129240  0.077489   0.046461   0.027857               63.2960
# 32     0.104680  0.059545   0.033870   0.019266               68.6620
# 33     0.066997  0.034086   0.017341   0.008823               81.0540
#
#     omega(2)=c11=11.3179*c0^0.5/c10     eps      lnT*       T*  \
# 0                           20.1410  942.32 -1.144600  0.31836
# 1                           19.2560  885.54 -1.002400  0.36701
# 2                           18.4430  838.28 -0.873420  0.41752
# 3                           17.6910  798.37 -0.755640  0.46971
# 4                           16.9940  764.25 -0.647420  0.52339
# 5                           16.3460  734.76 -0.547450  0.57842
# 6                           15.7440  709.03 -0.454650  0.63467
# 7                           15.1860  686.40 -0.368140  0.69202
# 8                           14.6680  666.35 -0.287200  0.75036
# 9                           14.1880  648.46 -0.211200  0.80961
# 10                          13.7430  632.41 -0.139620  0.86969
# 11                          13.3310  617.93 -0.072008  0.93052
# 12                          12.9500  604.81 -0.007980  0.99205
# 13                          12.5970  592.86  0.052799  1.05420
# 14                          12.2710  581.93  0.110620  1.11700
# 15                          11.9680  571.91  0.165740  1.18030
# 16                          11.6870  562.68  0.218380  1.24410
# 17                          11.4260  554.15  0.268740  1.30830
# 18                          11.1830  546.25  0.317000  1.37300
# 19                          10.9580  538.91  0.363320  1.43810
# 20                          10.7480  532.07  0.407830  1.50350
# 21                          10.3700  519.72  0.491940  1.63550
# 22                          10.0400  508.87  0.570210  1.76860
# 23                           9.7508  499.25  0.643360  1.90290
# 24                           9.4958  490.67  0.711980  2.03800
# 25                           9.0691  476.03  0.837580  2.31080
# 26                           8.7280  464.00  0.950190  2.58620
# 27                           8.4499  453.94  1.052200  2.86380
# 28                           8.2192  445.41  1.145200  3.14320
# 29                           8.0247  438.07  1.230800  3.42410
# 30                           7.8581  431.71  1.310000  3.70620
# 31                           7.5862  421.20  1.452400  4.27350
# 32                           7.3716  412.89  1.577700  4.84390
# 33                           6.9817  398.14  1.837200  6.27910
#
#     omega*=c16=1.6122-0.77503*c14+0.23797*c14^2+0.0021203*c14^3-0.014676*c14^4+0.0018846*c14^5  \
# 0                                             2.77890
# 1                                             2.60930
# 2                                             2.45980
# 3                                             2.32760
# 4                                             2.21040
# 5                                             2.10610
# 6                                             2.01290
# 7                                             1.92940
# 8                                             1.85430
# 9                                             1.78650
# 10                                            1.72500
# 11                                            1.66920
# 12                                            1.61840
# 13                                            1.57190
# 14                                            1.52940
# 15                                            1.49030
# 16                                            1.45430
# 17                                            1.42110
# 18                                            1.39040
# 19                                            1.36190
# 20                                            1.33550
# 21                                            1.28800
# 22                                            1.24660
# 23                                            1.21030
# 24                                            1.17840
# 25                                            1.12480
# 26                                            1.08190
# 27                                            1.04710
# 28                                            1.01840
# 29                                            0.99438
# 30                                            0.97411
# 31                                            0.94190
# 32                                            0.91759
# 33                                            0.87693
#
#        sig       S   S/sig  predicted _omega=c20=c18*c18*c16
# 0   2.6921  2.7783  1.0320                           21.4510
# 1   2.7165  2.7927  1.0281                           20.3510
# 2   2.7382  2.8055  1.0246                           19.3610
# 3   2.7569  2.8170  1.0218                           18.4700
# 4   2.7728  2.8272  1.0196                           17.6680
# 5   2.7859  2.8365  1.0182                           16.9450
# 6   2.7967  2.8450  1.0172                           16.2920
# 7   2.8055  2.8527  1.0168                           15.7010
# 8   2.8125  2.8597  1.0168                           15.1640
# 9   2.8181  2.8662  1.0171                           14.6760
# 10  2.8226  2.8722  1.0176                           14.2310
# 11  2.8260  2.8778  1.0183                           13.8240
# 12  2.8288  2.8829  1.0191                           13.4510
# 13  2.8309  2.8877  1.0201                           13.1080
# 14  2.8325  2.8922  1.0211                           12.7930
# 15  2.8338  2.8964  1.0221                           12.5020
# 16  2.8348  2.9003  1.0231                           12.2330
# 17  2.8355  2.9040  1.0241                           11.9840
# 18  2.8361  2.9075  1.0252                           11.7530
# 19  2.8366  2.9108  1.0262                           11.5390
# 20  2.8369  2.9139  1.0271                           11.3390
# 21  2.8375  2.9196  1.0289                           10.9780
# 22  2.8380  2.9247  1.0306                           10.6630
# 23  2.8384  2.9294  1.0321                           10.3860
# 24  2.8387  2.9336  1.0334                           10.1410
# 25  2.8395  2.9410  1.0357                            9.7289
# 26  2.8402  2.9473  1.0377                            9.3983
# 27  2.8407  2.9527  1.0394                            9.1289
# 28  2.8409  2.9573  1.0410                            8.9066
# 29  2.8408  2.9614  1.0425                            8.7208
# 30  2.8402  2.9651  1.0439                            8.5639
# 31  2.8380  2.9711  1.0469                            8.3148
# 32  2.8344  2.9761  1.0500                            8.1272
# 33  2.8216  2.9851  1.0579                            7.8142

# %%
target_visc = visc[['T(K)','viscosity(micro-Pas)']].values

# %%
target_visc
# Out:
# array([[ 300.    ,    9.7331],
#        [ 325.    ,   10.596 ],
#        [ 350.    ,   11.481 ],
#        [ 375.    ,   12.389 ],
#        [ 400.    ,   13.32  ],
#        [ 425.    ,   14.274 ],
#        [ 450.    ,   15.249 ],
#        [ 475.    ,   16.244 ],
#        [ 500.    ,   17.254 ],
#        [ 525.    ,   18.278 ],
#        [ 550.    ,   19.314 ],
#        [ 575.    ,   20.357 ],
#        [ 600.    ,   21.407 ],
#        [ 625.    ,   22.461 ],
#        [ 650.    ,   23.516 ],
#        [ 675.    ,   24.57  ],
#        [ 700.    ,   25.623 ],
#        [ 725.    ,   26.672 ],
#        [ 750.    ,   27.716 ],
#        [ 775.    ,   28.753 ],
#        [ 800.    ,   29.784 ],
#        [ 850.    ,   31.82  ],
#        [ 900.    ,   33.818 ],
#        [ 950.    ,   35.776 ],
#        [1000.    ,   37.691 ],
#        [1100.    ,   41.39  ],
#        [1200.    ,   44.92  ],
#        [1300.    ,   48.293 ],
#        [1400.    ,   51.523 ],
#        [1500.    ,   54.624 ],
#        [1600.    ,   57.612 ],
#        [1800.    ,   63.296 ],
#        [2000.    ,   68.662 ],
#        [2500.    ,   81.054 ]])

# %%
def viscosity(T, sig, eps):
    
    Tc = 
    Tr = T/Tc
    
    om_22 = omg.get(Tr, 2, 2)
    
    visc = 5*(mass*kb*T/np.pi)**0.5/(16*sig**2*)
    
    return visc

# %%
def loss_visc(params, target):
    # ignoring prefactor V/(k_B)^3
    # If P is only one (P->0), it can be included in the prefactor
    loss = 0.0
    for T, visc_t in target:
        if T < 1000.0:
            continue
        
        visc_m = viscosity(T, params[0], params[1])
        loss += ((visc_m - visc_t)/visc_t)**2

    return loss
# Out:
# Index(['T(K)', 'T/Tc', '(T/Tc)^0.5', '(T/Tc)^(-0.5)', '(T/Tc)^-1',
#        '(T/Tc)^(-1.5)', '(T/Tc)^(-2)', '()^-2.5', '()^-3', '()^-3.5',
#        'viscosity(micro-Pas)', 'omega(2)=c11=11.3179*c0^0.5/c10', 'eps',
#        'lnT*', 'T*',
#        'omega*=c16=1.6122-0.77503*c14+0.23797*c14^2+0.0021203*c14^3-0.014676*c14^4+0.0018846*c14^5',
#        'sig', 'S', 'S/sig', 'predicted _omega=c20=c18*c18*c16'],
#       dtype='object')

# %%
visc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 20 columns):
# T(K)                                                                                          34 non-null float64
# T/Tc                                                                                          34 non-null float64
# (T/Tc)^0.5                                                                                    34 non-null float64
# (T/Tc)^(-0.5)                                                                                 34 non-null float64
# (T/Tc)^-1                                                                                     34 non-null float64
# (T/Tc)^(-1.5)                                                                                 34 non-null float64
# (T/Tc)^(-2)                                                                                   34 non-null float64
# ()^-2.5                                                                                       34 non-null float64
# ()^-3                                                                                         34 non-null float64
# ()^-3.5                                                                                       34 non-null float64
# viscosity(micro-Pas)                                                                          34 non-null float64
# omega(2)=c11=11.3179*c0^0.5/c10                                                               34 non-null float64
# eps                                                                                           34 non-null float64
# lnT*                                                                                          34 non-null float64
# T*                                                                                            34 non-null float64
# omega*=c16=1.6122-0.77503*c14+0.23797*c14^2+0.0021203*c14^3-0.014676*c14^4+0.0018846*c14^5    34 non-null float64
# sig                                                                                           34 non-null float64
# S                                                                                             34 non-null float64
# S/sig                                                                                         34 non-null float64
# predicted _omega=c20=c18*c18*c16                                                              34 non-null float64
# dtypes: float64(20)
# memory usage: 5.4 KB

# %%
de = np.array([-33.41,-28.86,-22.27,-16.72,-8.93,-11.23])*4.184

# %%
de
# Out:
# array([-139.78744, -120.75024,  -93.17768,  -69.95648,  -37.36312,
#         -46.98632])

# %%
db = np.array([-43.77,-43.89,-38.39,-24.32,-7.29,-0.92])*4.184
db
# Out:
# array([-183.13368, -183.63576, -160.62376, -101.75488,  -30.50136,
#          -3.84928])

# %%
print(np.finfo(np.longdouble))
# Out:
# Machine parameters for float128
# ---------------------------------------------------------------
# precision =  18   resolution = 1.0000000000000000715e-18
# machep =    -63   eps =        1.084202172485504434e-19
# negep =     -64   epsneg =     5.42101086242752217e-20
# minexp = -16382   tiny =       3.3621031431120935063e-4932
# maxexp =  16384   max =        1.189731495357231765e+4932
# nexp =       15   min =        -max
# ---------------------------------------------------------------

# %%
print(np.finfo(np.float))
# Out:
# Machine parameters for float64
# ---------------------------------------------------------------
# precision =  15   resolution = 1.0000000000000001e-15
# machep =    -52   eps =        2.2204460492503131e-16
# negep =     -53   epsneg =     1.1102230246251565e-16
# minexp =  -1022   tiny =       2.2250738585072014e-308
# maxexp =   1024   max =        1.7976931348623157e+308
# nexp =       11   min =        -max
# ---------------------------------------------------------------

# %%
a = 5.5

# %%
b = np.longdouble(a)

# %%
b
# Out:
# 5.5

# %%
type(a), type(b)
# Out:
# (float, numpy.float128)

# %%
c = a/b

# %%
type(c)
# Out:
# numpy.float128
